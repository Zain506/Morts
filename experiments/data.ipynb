# %% [markdown]
# # Add to database

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# Import all methods from all files in src
from src.google import Google
from src.dataUpdate import DataUpdate
search = "Barrister UK site:linkedin.com/in"
results = Google(search).search()

# %%
tmp = DataUpdate("../data.csv", results.Links(), search=search).run()

# %%
tmp.updatedDf
# Out:
#                                                   url  \
# 0                 https://uk.linkedin.com/in/ndidi1st
# 1   https://uk.linkedin.com/in/simon-whitehead-a85...
# 2   https://uk.linkedin.com/in/david-henderson-648...
# 3   https://uk.linkedin.com/in/indro-mukerjee-5420a72
# 4               https://uk.linkedin.com/in/tomhashemi
# 5    https://uk.linkedin.com/in/malgorzata-kolakowska
# 6    https://uk.linkedin.com/in/colm-holmes-5a864412b
# 7           https://uk.linkedin.com/in/scott-a-davies
# 8           https://uk.linkedin.com/in/clarechapman13
# 9             https://uk.linkedin.com/in/mike-regnier
# 10  https://uk.linkedin.com/in/sir-harry-potter-o-...
# 11  https://uk.linkedin.com/in/damian-stuart-a28323b0
# 12   https://uk.linkedin.com/in/duncan-craig-95724133
# 13  https://uk.linkedin.com/in/natasha-hausdorff-7...
# 14                 https://uk.linkedin.com/in/zhen-ye
# 15         https://uk.linkedin.com/in/theshaunwallace
# ...
